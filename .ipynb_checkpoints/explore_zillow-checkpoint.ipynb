# %% [markdown]
# Ask at least 5 questions about the data, keeping in mind that your target variable is logerror. e.g. Is logerror significantly different for properties in LA County vs Orange County vs Ventura County?
#
# Answer those questions through a mix of statistical tests and visualizations.

# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import acquire
import prep
import wrangle
import feature
from scipy import stats

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings('ignore')

# %%
#bringing in our zillow data
df = acquire.get_zillow_data()

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# typeconstructiontypeid          77353
# storytypeid                     77525
# heatingorsystemtypeid           28005
# buildingclasstypeid             77560
# architecturalstyletypeid        77369
# airconditioningtypeid           52569
# basementsqft                    77525
# buildingqualitytypeid           27766
# calculatedbathnbr                 615
# decktypeid                      76961
# finishedfloor1squarefeet        71540
# calculatedfinishedsquarefeet      200
# finishedsquarefeet12             3655
# finishedsquarefeet13            77533
# finishedsquarefeet15            74548
# finishedsquarefeet50            71540
# finishedsquarefeet6             77189
# fireplacecnt                    69288
# fullbathcnt                       615
# garagecarcnt                    52058
# garagetotalsqft                 52058
# hashottuborspa                  76036
# lotsizesquarefeet                8257
# poolcnt                         61402
# poolsizesum                     76706
# pooltypeid10                    77110
# pooltypeid2                     76501
# pooltypeid7                     62497
# propertyzoningdesc              27100
# regionidcity                     1472
# regionidneighborhood            46602
# regionidzip                        50
# threequarterbathnbr             67470
# unitcnt                         26872
# yardbuildingsqft17              75182
# yardbuildingsqft26              77505
# yearbuilt                         269
# numberofstories                 59979
# fireplaceflag                   77403
# structuretaxvaluedollarcnt        115
# taxvaluedollarcnt                   1
# landtaxvaluedollarcnt               2
# taxamount                           5
# taxdelinquencyflag              74675
# taxdelinquencyyear              74675
# censustractandblock               247
# airconditioningdesc             52569
# architecturalstyledesc          77369
# buildingclassdesc               77560
# heatingorsystemdesc             28005
# storydesc                       77525
# typeconstructiondesc            77353
# dtype: int64

# %%
df = prep.prepare_zillow(df)

# %%
# split
train, validate, test, X_train, y_train, X_validate, y_validate, X_test, y_test = prep.train_validate_test(df, 'logerror')

# %% [markdown]
# Goals of exploration
#
# Can we see patterns, find signals in the data?
#
# What features are driving the outcome?
#
# Are there other features we can construct that have stronger relationships?
#
# Use Visualization and statistical testing to help answer these questions.
#
# We want to walk away from exploration with with modeling strategies (feature selection, algorithm selection, evaluation methods, for example).
#
# Agenda
#
# Wrangle data (acquire, prep, summarize, split)
#
# Identify questions to answer, hypotheses to test.

# %%
train.head()
# Out:
#        propertylandusetypeid  parcelid       id  bathroomcnt  bedroomcnt  \
# 20861                  261.0  14327133  1908205          2.5         3.0
# 65249                  261.0  12118853  2243290          3.0         3.0
# 43544                  261.0  14158628   861795          1.0         3.0
# 589                    261.0  13980139  1218864          2.5         4.0
# 44756                  261.0  10917554   837256          2.0         2.0
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 20861                2.5                        2305.0                2305.0
# 65249                3.0                        2746.0                2746.0
# 43544                1.0                        1161.0                1161.0
# 589                  2.5                        1550.0                1550.0
# 44756                2.0                        1502.0                1502.0
#
#          fips  fullbathcnt  ...  yearbuilt  structuretaxvaluedollarcnt  \
# 20861  6059.0          2.0  ...     2003.0                    419746.0
# 65249  6037.0          3.0  ...     1926.0                    404440.0
# 43544  6059.0          1.0  ...     1953.0                     40629.0
# 589    6059.0          2.0  ...     1955.0                     72897.0
# 44756  6037.0          2.0  ...     1962.0                    142282.0
#
#        taxvaluedollarcnt assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 20861          1725925.0         2016.0              1306179.0   21899.16
# 65249           898274.0         2016.0               493834.0   10444.06
# 43544           478000.0         2016.0               437371.0    5528.26
# 589             994464.0         2016.0               921567.0   10801.82
# 44756           711411.0         2016.0               569129.0    8601.88
#
#        censustractandblock  logerror  transactiondate  \
# 20861         6.059063e+13  0.016509       2017-03-28
# 65249         6.037463e+13  0.081133       2017-08-10
# 43544         6.059002e+13 -0.018976       2017-06-05
# 589           6.059063e+13  0.033034       2017-01-04
# 44756         6.037144e+13  0.019062       2017-06-08
#
#              propertylandusedesc
# 20861  Single Family Residential
# 65249  Single Family Residential
# 43544  Single Family Residential
# 589    Single Family Residential
# 44756  Single Family Residential
#
# [5 rows x 29 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28103 entries, 20861 to 24803
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   propertylandusetypeid         28103 non-null  float64
#  1   parcelid                      28103 non-null  int64
#  2   id                            28103 non-null  int64
#  3   bathroomcnt                   28103 non-null  float64
#  4   bedroomcnt                    28103 non-null  float64
#  5   calculatedbathnbr             28103 non-null  float64
#  6   calculatedfinishedsquarefeet  28103 non-null  float64
#  7   finishedsquarefeet12          28103 non-null  float64
#  8   fips                          28103 non-null  float64
#  9   fullbathcnt                   28103 non-null  float64
#  10  latitude                      28103 non-null  float64
#  11  longitude                     28103 non-null  float64
#  12  lotsizesquarefeet             28103 non-null  float64
#  13  propertycountylandusecode     28103 non-null  object
#  14  rawcensustractandblock        28103 non-null  float64
#  15  regionidcity                  28103 non-null  float64
#  16  regionidcounty                28103 non-null  float64
#  17  regionidzip                   28103 non-null  float64
#  18  roomcnt                       28103 non-null  float64
#  19  yearbuilt                     28103 non-null  float64
#  20  structuretaxvaluedollarcnt    28103 non-null  float64
#  21  taxvaluedollarcnt             28103 non-null  float64
#  22  assessmentyear                28103 non-null  float64
#  23  landtaxvaluedollarcnt         28103 non-null  float64
#  24  taxamount                     28103 non-null  float64
#  25  censustractandblock           28103 non-null  float64
#  26  logerror                      28103 non-null  float64
#  27  transactiondate               28103 non-null  object
#  28  propertylandusedesc           28103 non-null  object
# dtypes: float64(24), int64(2), object(3)
# memory usage: 6.4+ MB

# %%
# in the scope of exploration:
# - frame questions with our tools:
# - univariate exploration
# - bivariate exploration
# - multivariate exploration


# 1. univariate explorate
# - What are the distributions of each variables? 


# 2. Bivariate:
# - Does logerror score vary across fips


# 3. Bivariate:
# - Is there a relationship between logerror and bedroom count?


# 4. Is there a relationship between logerror and bathroom count?


# multivariate:
# 5. If we control for calculatedfinishedsqft, does logerror differ across tax amount

# 6. If we control for fullbathcnt, does logerror differ across yearbuilt?

# %%
for col in train.columns:
    plt.hist(train[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# notes:
#
# fips: 6037 (LA County) has the most entries. 6059 (Orange County) has the second most entries. 6111 (Ventura County) has the elast entries.
# bedroom count is almost normally distributed. bathroom count is slightly skewed right
# calculatedfinishedsqft is also almost normally distributed
# yearbuilt is almost normally distributed
# Exploration note:
#
# visualization for exploration should be fast and informative. It serves the purpose of elaborating on relationships in your data and potential drivers of your target

# %%
def get_zillow_heatmap(train):
    '''
    returns a heatmap and correlations of how each feature relates to logerror
    '''
    plt.figure(figsize=(8,12))
    heatmap = sns.heatmap(train.corr()[['logerror']].sort_values(by='logerror', ascending=False), vmin=-.5, vmax=.5, annot=True)
    heatmap.set_title('Feautures Correlating with Value')
    
    return heatmap

# %%
get_zillow_heatmap(train)
# Out:
# <AxesSubplot:title={'center':'Feautures Correlating with Value'}>

# %%
# 2. Bivariate:
# - Does logerror score vary across fips

# %%
sns.boxplot(train.fips, train.logerror)
plt.title('Potential difference in logerror across county?')
plt.show()

# %%
# Null hypothesis: mean_LACounty == mean_OrangeCounty
# presume alpha of 0.05


stats.levene(train[train.fips==6037].logerror, train[train.fips==6059].logerror)
# Out:
# LeveneResult(statistic=22.777819347336138, pvalue=1.8285204299120428e-06)

# %%
stats.ttest_ind(train[train.fips==6037].logerror, train[train.fips==6059].logerror, equal_var=False)
# Out:
# Ttest_indResult(statistic=-3.3242253754734894, pvalue=0.000889276156137224)

# %% [markdown]
# we can reject the null hypothesis. there is evidence to suggest a signififfcant difference in the means between the two groups

# %%
# 3. Bivariate:
# - Is there a relationship between logerror and bedroom count?

# %%
print('Relationship between bedroom count and logerror(?)')
sns.jointplot(x='bedroomcnt', y='logerror', data=train)
plt.xlabel('Bedroom count')
plt.ylabel('Logerror')
plt.show()
# Out:
# Relationship between bedroom count and logerror(?)

# %%
# no noted explicit linear correlation

# %%
# 4. Is there a relationship between logerror and bathroom count?

# %%
# bin bathroom count
train['bathroomcnt_bin'] = pd.cut(train.bathroomcnt,[0,3,5])

# %%
sns.boxplot(train.bathroomcnt_bin, train.logerror)
plt.title('Logerror across bathroom count')
plt.show()

# %%
# H0: mean_under_3 == mean_over_3
stats.ttest_ind(train[train.bathroomcnt <= 3].logerror, train[train.bathroomcnt > 3].logerror, equal_var=True)
# Out:
# Ttest_indResult(statistic=-3.303872301961076, pvalue=0.0009547842947391102)

# %%
# Fail to reject the null hypothesis: We do not have an implied difference between the bathroom count groups of the logerror
# Conclusion: No difference between the means, no significant r value to be concluded

# %%
plt.figure(figsize=(8,8))
sns.jointplot(x=train.calculatedfinishedsquarefeet.values, y=train.logerror.values, size=10,kind="hex",color="#34495e",)
plt.title('Log Error across Calculated Finished Square Feet ')
plt.ylabel('Log Error', fontsize=12,)
plt.xlabel('Calculated Finished Square Feet', fontsize=12)
plt.show()

# %%
# multivariate:
# 5. If we control for calculatedfinishedsqft, does logerror differ across tax amount

# %%
sns.scatterplot(x='taxamount', y='logerror', data=train[train.calculatedfinishedsquarefeet <= 1500])
plt.title('Tax amount vs log error for those under 1500 square feet')
plt.show()

# %%
sns.scatterplot(x='taxamount', y='logerror', data=train[train.calculatedfinishedsquarefeet >= 1500])
plt.title('Tax amount vs Log error for those over 1500 square feet')
plt.show()

# %%
sns.scatterplot(x='taxamount', y='logerror', data=train[train.calculatedfinishedsquarefeet <= 1500], color='blue')
sns.scatterplot(x='taxamount', y='logerror', data=train[(train.calculatedfinishedsquarefeet > 1500) & (train.calculatedfinishedsquarefeet <=3857)], color='red')
plt.title('Tax amount vs Logerror for those under 1500 sqft. to those between 1500 and 3857 sqft.')
plt.show()

# %%
stats.ttest_ind(train[train.calculatedfinishedsquarefeet <= 1500].logerror, train[train.calculatedfinishedsquarefeet > 1500].logerror, equal_var=True)
# Out:
# Ttest_indResult(statistic=-0.2795282049919028, pvalue=0.779841553108217)

# %%
# county (fips) affecting this?

# %%
sns.scatterplot(x='taxamount', y='logerror', data=train[train.calculatedfinishedsquarefeet <=1500], hue='fips', palette='bright')
plt.title('County accounting for upper vs lower in square feet groups?')
plt.show()

# %%
# 6. If we control for bathroom count, does logerror differ across yearbuilt?

# %%
train['fullbathcnt_bin'] = pd.cut(train.fullbathcnt, [0, 3, 5, 7])

# %%
sns.scatterplot(x='yearbuilt', y='logerror', data=train, hue='fullbathcnt_bin')
plt.title('Year built to Logerror controlling for Full bathroom count Bins')
plt.show()

# %%
# takeaways: houses in the (3,5) bin for bathrooms seem newer. (0,3) bin has a consistent spread. (5,7) are mostly newer.
# no strong observable correlations

# %%
cols = ['logerror', 'bathroomcnt', 'bedroomcnt', 'calculatedfinishedsquarefeet', 'latitude', 
        'longitude','propertylandusedesc', 'yearbuilt', 'taxvaluedollarcnt', 'bathroomcnt_bin', 'fips']

# %%
sns.pairplot(data = train[cols].sample(10000), hue='fips', palette='bright')

# %%
from matplotlib import pylab
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot
fig = pylab.figure()
fig.set_size_inches(15,20)
ax = plt.axes(projection='3d')

ax.scatter(train.bathroomcnt, train.bedroomcnt, train.logerror,cmap='viridis')
ax.set_xlabel('Bathroom Count')
ax.set_ylabel('Bedroom Count')
ax.set_zlabel('Log Error');
pyplot.show()

# %%
# Out of what we have observed from our overall questions:
# No notable correlations observed from questions pointed thus far
# significant means difference across county for logerror (drivers not yet known)
# Potential groupings on bathroomcount brackets that could lead to logerror score
